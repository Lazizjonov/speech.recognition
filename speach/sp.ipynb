# %%
import sounddevice as sd
from matplotlib import pyplot as plt
import time
from numpy import fft
import soundfile as sf

# %%
rec = sd.rec(3 * 44100, channels=1, samplerate=44100, dtype='float64')
sd.wait()

# %%
plt.plot(rec)
plt.show()

# %%
sd.play(rec)
sd.wait()

# %%
sd.play(rec[50000:60000])
sd.wait()

plt.plot(rec[50000:60000])
plt.show()

# %%
""" 

1. Program to develop:
It should be able to differ vowels. Return number from 0 (very similar) to 10 (completely different).

2. Program to develop:
Store recordings (vowels, words, sentences) in affordable format.

3. Program to develop:
Compares new vowels from recorded ones if not similar to recorded ones than record it to store the data.

4. Program to develop:
Make a flag that changes program to play recording from vowels in memory.

Result: We can test different algorithms that compare vowels and check their efficiency by playing recordings with the similar vowels in memory.

"""
# Out:
# ' \n\n1. Program to develop:\nIt should be able to differ vowels. Return number from 0 (very similar) to 10 (completely different).\n\n2. Program to develop:\nStore recordings (vowels, words, sentences) in affordable format.\n\n3. Program to develop:\nCompares new vowels from recorded ones if not similar to recorded ones than record it to store the data.\n\n4. Program to develop:\n\n'
